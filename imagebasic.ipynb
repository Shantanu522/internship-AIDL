# %%
# !py -m pip install opencv-python
# !py -m pip install matplotlib
# !py -m pip install pillow
# !py -m pip install scikit-image
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import matplotlib.pyplot as plt
import skimage
img1=cv2.imread('1.jpg')
cv2.imshow('1',img1)
cv2.waitKey(0)
# Out:
# -1

# %%
import skimage
from skimage import io

img = io.imread('1.jpg')
io.imshow(img)
io.show()


img1 = io.imread('2.jpg')
io.imshow(img1)
io.show()

img2 = io.imread('3.jpg')
io.imshow(img2)
io.show()

# %%
img1.shape
img1
# Out:
# array([[[211, 128,  76],
#         [208, 125,  73],
#         [208, 123,  73],
#         ...,
#         [175, 129, 225],
#         [175, 129, 225],
#         [177, 131, 227]],
#
#        [[210, 127,  75],
#         [207, 124,  72],
#         [206, 121,  71],
#         ...,
#         [174, 128, 224],
#         [175, 129, 225],
#         [175, 129, 225]],
#
#        [[208, 125,  73],
#         [208, 125,  73],
#         [208, 124,  72],
#         ...,
#         [174, 130, 225],
#         [173, 129, 224],
#         [173, 129, 224]],
#
#        ...,
#
#        [[ 29,  15,  16],
#         [ 29,  15,  16],
#         [ 25,  11,  12],
#         ...,
#         [ 24,  14,  26],
#         [ 20,  12,  23],
#         [ 34,  26,  37]],
#
#        [[ 34,  17,  20],
#         [ 39,  22,  25],
#         [ 24,   7,  10],
#         ...,
#         [ 14,   6,  13],
#         [ 12,   5,  12],
#         [ 29,  23,  28]],
#
#        [[ 19,   2,   5],
#         [ 30,  13,  16],
#         [ 25,   8,  11],
# ...

# %%
img2=cv2.imread('2.jpg')
cv2.imshow('2',img2)
cv2.waitKey(0)
# Out:
# -1

# %%
img2.shape
img2
# Out:
# array([[[167, 124,  85],
#         [165, 126,  88],
#         [182, 151, 120],
#         ...,
#         [168, 138, 121],
#         [215, 203, 199],
#         [112, 109, 111]],
#
#        [[175, 126,  86],
#         [158, 113,  76],
#         [177, 139, 107],
#         ...,
#         [201, 169, 150],
#         [164, 149, 140],
#         [ 95,  89,  84]],
#
#        [[183, 124,  79],
#         [156, 101,  62],
#         [168, 121,  90],
#         ...,
#         [167, 133, 109],
#         [ 66,  42,  24],
#         [ 28,  12,   0]],
#
#        ...,
#
#        [[ 76,   0,  81],
#         [ 76,   0,  81],
#         [ 76,   0,  81],
#         ...,
#         [  0,   7,  10],
#         [  1,   7,  12],
#         [  1,   7,  12]],
#
#        [[ 76,   1,  79],
#         [ 76,   1,  79],
#         [ 76,   1,  79],
#         ...,
#         [  2,   7,  10],
#         [  3,   7,  12],
#         [  3,   7,  12]],
#
#        [[ 77,   2,  80],
#         [ 77,   2,  80],
#         [ 77,   2,  80],
# ...

# %%
img3=cv2.imread('3.jpg')
cv2.imshow('3',img3)
cv2.waitKey(0)
# Out:
# -1

# %%
img3.shape
img3
# Out:
# array([[[138,  90,  54],
#         [140,  92,  56],
#         [137,  89,  53],
#         ...,
#         [ 62,  18,  49],
#         [ 65,  21,  52],
#         [ 66,  22,  53]],
#
#        [[139,  91,  55],
#         [139,  91,  55],
#         [137,  89,  53],
#         ...,
#         [ 61,  17,  48],
#         [ 64,  20,  51],
#         [ 63,  19,  50]],
#
#        [[140,  92,  56],
#         [138,  90,  54],
#         [137,  89,  53],
#         ...,
#         [ 61,  17,  46],
#         [ 62,  18,  47],
#         [ 60,  16,  45]],
#
#        ...,
#
#        [[ 60,  31,   0],
#         [ 62,  33,   2],
#         [ 61,  33,   3],
#         ...,
#         [ 37,  10,  19],
#         [ 39,  12,  21],
#         [ 39,  12,  21]],
#
#        [[ 61,  32,   1],
#         [ 63,  34,   3],
#         [ 61,  33,   3],
#         ...,
#         [ 39,  12,  21],
#         [ 40,  13,  22],
#         [ 40,  13,  22]],
#
#        [[ 62,  34,   3],
#         [ 62,  34,   3],
#         [ 60,  32,   2],
# ...

# %%
import numpy as np
r2=np.random.randint(0,255,(50,50))
plt.imshow(r2,cmap='gray')

# %%
import numpy as np
import matplotlib.pyplot as plt
img=np.ones((50,50,3),dtype='uint8')*255
img[:25,:25,1:]=0
img[:25,25:,::2]=0
img[25:,:25,:2]=0
img[25:,25:,2:]=0
plt.imshow(img)

# %%
plt.imsave('coloursquare.png',img)

# %%
#skimage.io.imsave('squarebox.png',img)
#cv2.imwrite('squarebox.png',img)

# %%
# cv2.imshow('1',img)
# cv2.waitKey(0)
# cv2.imwrite('cv2 save.png',img2[:,:,::-1])

# %%
import skimage
plt.imshow(img[:,:,::-1])
skimage.io.imshow(img[:,:,::-1])
